# %% [markdown]
# # Create label for training in future

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
meta = pd.read_csv('../meta_info.csv')

# %%
meta.head()
# Out:
#    patient_id  nodule_no  slice_no                      original_image  \
# 0           1          0         0  LIDC-IDRI-0001/0001_NI000_slice000
# 1           1          0         1  LIDC-IDRI-0001/0001_NI000_slice001
# 2           1          0         2  LIDC-IDRI-0001/0001_NI000_slice002
# 3           1          0         3  LIDC-IDRI-0001/0001_NI000_slice003
# 4           1          0         4  LIDC-IDRI-0001/0001_NI000_slice004
#
#                            mask_image  malignancy is_cancer  is_clean
# 0  LIDC-IDRI-0001/0001_MA000_slice000           5      True     False
# 1  LIDC-IDRI-0001/0001_MA000_slice001           5      True     False
# 2  LIDC-IDRI-0001/0001_MA000_slice002           5      True     False
# 3  LIDC-IDRI-0001/0001_MA000_slice003           5      True     False
# 4  LIDC-IDRI-0001/0001_MA000_slice004           5      True     False

# %%
# NI= Nodule Image, MA = Mask Original , CN = Clean Nodule , CM = Clean Mask

# %%
def is_nodule(row):
    if row[20:22] =='NI':
        return True
    else:
        return False

# %%
meta['is_nodule']= meta['original_image'].apply(lambda row: is_nodule(row))

# %%
# Lets separate Clean meta and meta data
clean_meta = meta[meta['is_nodule']==False]
clean_meta.reset_index(inplace=True)
meta = meta[meta['is_nodule']==True]
meta.reset_index(inplace=True)

# %%
clean_meta.head(2)
# Out:
#    index  patient_id  nodule_no  slice_no                      original_image  \
# 0    378          28          0         0  LIDC-IDRI-0028/0028_CN001_slice000
# 1    379          28          1         1  LIDC-IDRI-0028/0028_CN001_slice001
#
#                            mask_image  malignancy is_cancer  is_clean  \
# 0  LIDC-IDRI-0028/0028_CM001_slice000           0     False      True
# 1  LIDC-IDRI-0028/0028_CM001_slice001           0     False      True
#
#    is_nodule
# 0      False
# 1      False

# %%
meta.head(2)
# Out:
#    index  patient_id  nodule_no  slice_no                      original_image  \
# 0      0           1          0         0  LIDC-IDRI-0001/0001_NI000_slice000
# 1      1           1          0         1  LIDC-IDRI-0001/0001_NI000_slice001
#
#                            mask_image  malignancy is_cancer  is_clean  \
# 0  LIDC-IDRI-0001/0001_MA000_slice000           5      True     False
# 1  LIDC-IDRI-0001/0001_MA000_slice001           5      True     False
#
#    is_nodule
# 0       True
# 1       True

# %%
def is_train(row,train,val,test):
    if row in train:
        return 'Train'
    elif row in val:
        return 'Validation'
    else:
        return 'Test'

# %%
clean_patient_id = list(np.unique(clean_meta['patient_id']))
meta_patient_id = list(np.unique(meta['patient_id']))

# %%
def create_label_segmentation(meta):
    patient_id = list(np.unique(meta['patient_id']))
    train_patient , test_patient = train_test_split(patient_id,test_size= 0.2)
    train_patient, val_patient = train_test_split(train_patient,test_size= 0.25)
    print(len(train_patient),len(val_patient),len(test_patient))
    
    meta['data_split']= meta['patient_id'].apply(lambda row : is_train(row,train_patient,val_patient,test_patient))
    
    return meta

# %%
# We need to train/test split independently for clean_meta, meta
meta = create_label_segmentation(meta)
clean_meta = create_label_segmentation(clean_meta)
# Out:
# 525 175 175
# 81 27 27

# %%
meta.head()
# Out:
#    index  patient_id  nodule_no  slice_no                      original_image  \
# 0      0           1          0         0  LIDC-IDRI-0001/0001_NI000_slice000
# 1      1           1          0         1  LIDC-IDRI-0001/0001_NI000_slice001
# 2      2           1          0         2  LIDC-IDRI-0001/0001_NI000_slice002
# 3      3           1          0         3  LIDC-IDRI-0001/0001_NI000_slice003
# 4      4           1          0         4  LIDC-IDRI-0001/0001_NI000_slice004
#
#                            mask_image  malignancy is_cancer  is_clean  \
# 0  LIDC-IDRI-0001/0001_MA000_slice000           5      True     False
# 1  LIDC-IDRI-0001/0001_MA000_slice001           5      True     False
# 2  LIDC-IDRI-0001/0001_MA000_slice002           5      True     False
# 3  LIDC-IDRI-0001/0001_MA000_slice003           5      True     False
# 4  LIDC-IDRI-0001/0001_MA000_slice004           5      True     False
#
#    is_nodule data_split
# 0       True      Train
# 1       True      Train
# 2       True      Train
# 3       True      Train
# 4       True      Train

# %%
clean_meta.head()
# Out:
#    index  patient_id  nodule_no  slice_no                      original_image  \
# 0    378          28          0         0  LIDC-IDRI-0028/0028_CN001_slice000
# 1    379          28          1         1  LIDC-IDRI-0028/0028_CN001_slice001
# 2    380          28          2         2  LIDC-IDRI-0028/0028_CN001_slice002
# 3    381          28          3         3  LIDC-IDRI-0028/0028_CN001_slice003
# 4    382          28          4         4  LIDC-IDRI-0028/0028_CN001_slice004
#
#                            mask_image  malignancy is_cancer  is_clean  \
# 0  LIDC-IDRI-0028/0028_CM001_slice000           0     False      True
# 1  LIDC-IDRI-0028/0028_CM001_slice001           0     False      True
# 2  LIDC-IDRI-0028/0028_CM001_slice002           0     False      True
# 3  LIDC-IDRI-0028/0028_CM001_slice003           0     False      True
# 4  LIDC-IDRI-0028/0028_CM001_slice004           0     False      True
#
#    is_nodule data_split
# 0      False      Train
# 1      False      Train
# 2      False      Train
# 3      False      Train
# 4      False      Train

# %%
# Clean Meta only stores meta information of patients without nodules.

# %%
meta.to_csv('/home/LUNG_DATA/meta_csv/meta.csv')
clean_meta.to_csv('/home/LUNG_DATA/meta_csv/clean_meta.csv')
